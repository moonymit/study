# %%
import numpy as np
import tensorflow as tf
import random

class DQN:
    def __init__(self, session, input_size, output_size, name="main"):
        
        self.session = session
        self.input_size = input_size
        self.output_size = output_size
        self.net_name = name
        
        self.build_network()

    
    # h_size: hidden size, l_rate: learning rate
    def build_network(self, h_size = 10, l_rate = 1e-1):
        with tf.variable_scope(self.net_name):
            self._X=tf.placeholder(dtype=tf.float32, shape=[None, self.input_size])

            # First layer of weights
            W1 = tf.get_variable('W1', shape=[self.input_size, h_size], 
                                 initializer=tf.contrib.layers.xavier_initializer())
            layer1 = tf.nn.tanh(tf.matmul(self._X, W1))

            # Second layer of weights
            W2 = tf.get_variable('W2', shape=[h_size, self.output_size], 
                                 initializer=tf.contrib.layers.xavier_initializer())

            # Q prediction
            self._Qpred = tf.matmul(layer1, W2)
        
        # We need to define the parts of the network needed for learning a polilcy
        self._Y = tf.placeholder(dtype=tf.float32, shape=[None, self.output_size])
        
        # Loss function
        self._loss = tf.reduce_sum(tf.square(self._Y - self._Qpred))
        
        # Learning
        self._train = tf.train.AdamOptimizer(learning_rate=l_rate).minimize(self._loss)
    

    def predict(self, state):
        s_t = np.reshape(state, [1,self.input_size])
        return self.session.run(self._Qpred, feed_dict={self._X: s_t})

    
    def update(self, x_stack, y_stack):
        return self.session.run([self._loss, self._train], feed_dict={self._X: x_stack, self._Y: y_stack})

# %%
from collections import deque
import gym
from gym.envs.registration import register

env = gym.make('CartPole-v0')
env._max_episode_steps = 10004

input_size = env.observation_space.shape[0]
output_size = env.action_space.n

dis = 0.9
REPLAY_MEMORY = 50000

def simple_replay_train(DQN, train_batch):
    x_stack = np.empty(0).reshape(0, DQN.input_size)
    y_stack = np.empty(0).reshape(0, DQN.output_size)
    
    # Get stored information from the buffer
    for state, action, reward, next_state, done in train_batch:
        Q = DQN.predict(state)
        
        # terminal?
        if done:
            Q[0, action] = reward
        else:
            # Obtain the Q' values by feeding the new state through our network
            Q[0, action] = reward + dis * np.max(DQN.predict(next_state))
            
        y_stack = np.vstack([y_stack, Q])
        x_stack = np.vstack([x_stack, state])
    
    # Train our network using target and predicted Q values on each episode
    return DQN.update(x_stack, y_stack)


def bot_play(mainDQN):
    # See our trained network in action
    s = env.reset()
    reward_sum = 0
    while True:
        env.render()
        a = np.argmax(mainDQN.predict(s))
        s, reward, done, _ = env.step(a)
        reward_sum += reward
        if done:
            print("Total score: {}".format(reward_sum))
            break
            

def main():
    max_episodes = 5000
    
    # store the previus observations in replay memory
    replay_buffer = deque()
    
    with tf.Session() as sess:
        mainDQN = DQN(sess, input_size, output_size)
        tf.global_variables_initializer().run()
        
        for episode in range(max_episodes):
            e = 1. / ((episode / 10) + 1)
            done = False
            step_count = 0
            
            state = env.reset()
            
            while not done:
                if np.random.rand(1) < e:
                    action = env.action_space.sample()
                else:
                    #choose an action by greedily from the Q-network
                    action = np.argmax(mainDQN.predict(state))
                    
                # Get new state and reward from environment
                next_state, reward, done, _ = env.step(action)
                if done and step_count < (env._max_episode_steps-1):
                    reward = -100
                    
                # Save the experience to our buffer
                replay_buffer.append((state, action, reward, next_state, done))
                
                if len(replay_buffer) > REPLAY_MEMORY:
                    replay_buffer.popleft()
                    
                state = next_state
                step_count += 1
                if step_count > 10000: # Enough
                    break
                    
            print("Episode: {} Step: {}".format(episode, step_count))
            if step_count > 10000:
                pass
                break
            
            if episode % 10 == 1: # train every 10 episodes
                # Get a random batch of experiences.
                for _ in range(50):
                    #Minibatch works better
                    minibatch = random.sample(replay_buffer, 10)
                    loss, _ = simple_replay_train(mainDQN, minibatch)
                print("Loss :", loss)
            
        bot_play(mainDQN)
# Out:
# [2017-08-03 03:59:35,631] Making new env: CartPole-v0

# %%
if __name__ == "__main__":
    main()
# Out:
# Episode: 0 Step: 12
# Episode: 1 Step: 11
# Loss : 2981.37
# Episode: 2 Step: 19
# Episode: 3 Step: 19
# Episode: 4 Step: 11
# Episode: 5 Step: 27
# Episode: 6 Step: 16
# Episode: 7 Step: 13
# Episode: 8 Step: 11
# Episode: 9 Step: 12
# Episode: 10 Step: 12
# Episode: 11 Step: 10
# Loss : 9468.02
# Episode: 12 Step: 10
# Episode: 13 Step: 11
# Episode: 14 Step: 11
# Episode: 15 Step: 12
# Episode: 16 Step: 9
# Episode: 17 Step: 9
# Episode: 18 Step: 16
# Episode: 19 Step: 9
# Episode: 20 Step: 10
# Episode: 21 Step: 10
# Loss : 9417.37
# Episode: 22 Step: 19
# Episode: 23 Step: 23
# Episode: 24 Step: 15
# Episode: 25 Step: 22
# Episode: 26 Step: 15
# Episode: 27 Step: 20
# Episode: 28 Step: 33
# Episode: 29 Step: 39
# Episode: 30 Step: 10
# Episode: 31 Step: 10
# Loss : 141.718
# Episode: 32 Step: 21
# Episode: 33 Step: 21
# Episode: 34 Step: 18
# Episode: 35 Step: 28
# Episode: 36 Step: 18
# Episode: 37 Step: 19
# Episode: 38 Step: 21
# Episode: 39 Step: 15
# Episode: 40 Step: 12
# Episode: 41 Step: 18
# Loss : 9871.15
# Episode: 42 Step: 57
# Episode: 43 Step: 38
# Episode: 44 Step: 65
# Episode: 45 Step: 50
# Episode: 46 Step: 39
# Episode: 47 Step: 36
# Episode: 48 Step: 56
# Episode: 49 Step: 49
# Episode: 50 Step: 34
# Episode: 51 Step: 43
# Loss : 277.963
# Episode: 52 Step: 14
# Episode: 53 Step: 38
# Episode: 54 Step: 16
# Episode: 55 Step: 24
# Episode: 56 Step: 25
# Episode: 57 Step: 26
# Episode: 58 Step: 17
# Episode: 59 Step: 45
# Episode: 60 Step: 30
# Episode: 61 Step: 19
# Loss : 41.5924
# Episode: 62 Step: 76
# Episode: 63 Step: 92
# Episode: 64 Step: 66
# Episode: 65 Step: 88
# Episode: 66 Step: 87
# Episode: 67 Step: 65
# Episode: 68 Step: 66
# Episode: 69 Step: 48
# Episode: 70 Step: 49
# Episode: 71 Step: 99
# Loss : 19225.0
# Episode: 72 Step: 29
# Episode: 73 Step: 26
# Episode: 74 Step: 43
# Episode: 75 Step: 39
# Episode: 76 Step: 53
# Episode: 77 Step: 33
# Episode: 78 Step: 59
# Episode: 79 Step: 35
# Episode: 80 Step: 26
# Episode: 81 Step: 29
# Loss : 9068.83
# Episode: 82 Step: 21
# Episode: 83 Step: 22
# Episode: 84 Step: 38
# Episode: 85 Step: 21
# Episode: 86 Step: 23
# Episode: 87 Step: 32
# Episode: 88 Step: 23
# Episode: 89 Step: 28
# Episode: 90 Step: 19
# Episode: 91 Step: 44
# Loss : 720.462
# Episode: 92 Step: 43
# Episode: 93 Step: 60
# Episode: 94 Step: 64
# Episode: 95 Step: 52
# Episode: 96 Step: 61
# Episode: 97 Step: 99
# Episode: 98 Step: 50
# Episode: 99 Step: 50
# Episode: 100 Step: 45
# Episode: 101 Step: 50
# Loss : 53.7367
# Episode: 102 Step: 63
# Episode: 103 Step: 33
# Episode: 104 Step: 21
# Episode: 105 Step: 32
# Episode: 106 Step: 49
# Episode: 107 Step: 18
# Episode: 108 Step: 36
# Episode: 109 Step: 34
# Episode: 110 Step: 61
# Episode: 111 Step: 23
# Loss : 46.2712
# Episode: 112 Step: 65
# Episode: 113 Step: 38
# Episode: 114 Step: 30
# Episode: 115 Step: 24
# Episode: 116 Step: 91
# Episode: 117 Step: 59
# Episode: 118 Step: 31
# Episode: 119 Step: 45
# Episode: 120 Step: 30
# Episode: 121 Step: 25
# Loss : 20207.8
# Episode: 122 Step: 18
# Episode: 123 Step: 17
# Episode: 124 Step: 23
# Episode: 125 Step: 21
# Episode: 126 Step: 14
# Episode: 127 Step: 23
# Episode: 128 Step: 18
# Episode: 129 Step: 19
# Episode: 130 Step: 14
# Episode: 131 Step: 19
# Loss : 692.121
# Episode: 132 Step: 32
# Episode: 133 Step: 21
# Episode: 134 Step: 38
# Episode: 135 Step: 15
# Episode: 136 Step: 29
# Episode: 137 Step: 16
# Episode: 138 Step: 15
# Episode: 139 Step: 23
# Episode: 140 Step: 15
# Episode: 141 Step: 30
# Loss : 229.071
# Episode: 142 Step: 24
# Episode: 143 Step: 35
# Episode: 144 Step: 41
# Episode: 145 Step: 42
# Episode: 146 Step: 16
# Episode: 147 Step: 44
# Episode: 148 Step: 55
# Episode: 149 Step: 55
# Episode: 150 Step: 32
# Episode: 151 Step: 21
# Loss : 19618.0
# Episode: 152 Step: 9
# Episode: 153 Step: 10
# Episode: 154 Step: 9
# Episode: 155 Step: 9
# Episode: 156 Step: 9
# Episode: 157 Step: 9
# Episode: 158 Step: 10
# Episode: 159 Step: 9
# Episode: 160 Step: 9
# Episode: 161 Step: 10
# Loss : 79.3482
# Episode: 162 Step: 21
# Episode: 163 Step: 39
# Episode: 164 Step: 19
# Episode: 165 Step: 10
# Episode: 166 Step: 45
# Episode: 167 Step: 23
# Episode: 168 Step: 25
# Episode: 169 Step: 13
# Episode: 170 Step: 32
# Episode: 171 Step: 37
# Loss : 977.365
# Episode: 172 Step: 44
# Episode: 173 Step: 38
# Episode: 174 Step: 33
# Episode: 175 Step: 33
# Episode: 176 Step: 37
# Episode: 177 Step: 31
# Episode: 178 Step: 70
# Episode: 179 Step: 44
# Episode: 180 Step: 39
# Episode: 181 Step: 49
# Loss : 207.864
# Episode: 182 Step: 10
# Episode: 183 Step: 9
# Episode: 184 Step: 9
# Episode: 185 Step: 10
# Episode: 186 Step: 10
# Episode: 187 Step: 10
# Episode: 188 Step: 9
# Episode: 189 Step: 10
# Episode: 190 Step: 10
# Episode: 191 Step: 10
# Loss : 37.9413
# Episode: 192 Step: 28
# Episode: 193 Step: 30
# Episode: 194 Step: 58
# Episode: 195 Step: 46
# Episode: 196 Step: 87
# Episode: 197 Step: 50
# Episode: 198 Step: 33
# Episode: 199 Step: 51
# Episode: 200 Step: 45
# Episode: 201 Step: 36
# Loss : 256.859
# Episode: 202 Step: 37
# Episode: 203 Step: 86
# Episode: 204 Step: 69
# Episode: 205 Step: 35
# Episode: 206 Step: 45
# Episode: 207 Step: 35
# Episode: 208 Step: 26
# Episode: 209 Step: 27
# Episode: 210 Step: 35
# Episode: 211 Step: 47
# Loss : 9745.49
# Episode: 212 Step: 31
# Episode: 213 Step: 23
# Episode: 214 Step: 18
# Episode: 215 Step: 18
# Episode: 216 Step: 39
# Episode: 217 Step: 31
# Episode: 218 Step: 47
# Episode: 219 Step: 60
# Episode: 220 Step: 17
# Episode: 221 Step: 23
# Loss : 182.027
# Episode: 222 Step: 43
# Episode: 223 Step: 16
# Episode: 224 Step: 44
# Episode: 225 Step: 24
# Episode: 226 Step: 13
# Episode: 227 Step: 12
# Episode: 228 Step: 32
# Episode: 229 Step: 26
# Episode: 230 Step: 28
# Episode: 231 Step: 22
# Loss : 129.999
# Episode: 232 Step: 9
# Episode: 233 Step: 20
# Episode: 234 Step: 18
# Episode: 235 Step: 13
# Episode: 236 Step: 34
# Episode: 237 Step: 12
# Episode: 238 Step: 9
# Episode: 239 Step: 10
# Episode: 240 Step: 9
# Episode: 241 Step: 9
# Loss : 103.253
# Episode: 242 Step: 28
# Episode: 243 Step: 26
# Episode: 244 Step: 17
# Episode: 245 Step: 21
# Episode: 246 Step: 25
# Episode: 247 Step: 23
# Episode: 248 Step: 16
# Episode: 249 Step: 24
# Episode: 250 Step: 16
# Episode: 251 Step: 18
# Loss : 179.295
# Episode: 252 Step: 17
# Episode: 253 Step: 29
# Episode: 254 Step: 48
# Episode: 255 Step: 31
# Episode: 256 Step: 18
# Episode: 257 Step: 31
# Episode: 258 Step: 51
# Episode: 259 Step: 34
# Episode: 260 Step: 17
# Episode: 261 Step: 20
# Loss : 190.159
# Episode: 262 Step: 28
# Episode: 263 Step: 34
# Episode: 264 Step: 28
# Episode: 265 Step: 62
# Episode: 266 Step: 24
# Episode: 267 Step: 44
# Episode: 268 Step: 29
# Episode: 269 Step: 23
# Episode: 270 Step: 30
# Episode: 271 Step: 55
# Loss : 90.9261
# Episode: 272 Step: 20
# Episode: 273 Step: 29
# Episode: 274 Step: 33
# Episode: 275 Step: 21
# Episode: 276 Step: 16
# Episode: 277 Step: 24
# Episode: 278 Step: 37
# Episode: 279 Step: 48
# Episode: 280 Step: 20
# Episode: 281 Step: 21
# Loss : 608.142
# Episode: 282 Step: 50
# Episode: 283 Step: 70
# Episode: 284 Step: 51
# Episode: 285 Step: 31
# Episode: 286 Step: 56
# Episode: 287 Step: 91
# Episode: 288 Step: 39
# Episode: 289 Step: 56
# Episode: 290 Step: 49
# Episode: 291 Step: 30
# Loss : 10211.5
# Episode: 292 Step: 8
# Episode: 293 Step: 29
# Episode: 294 Step: 24
# Episode: 295 Step: 9
# Episode: 296 Step: 40
# Episode: 297 Step: 23
# Episode: 298 Step: 46
# Episode: 299 Step: 21
# Episode: 300 Step: 24
# Episode: 301 Step: 28
# Loss : 826.717
# Episode: 302 Step: 64
# Episode: 303 Step: 65
# Episode: 304 Step: 37
# Episode: 305 Step: 48
# Episode: 306 Step: 51
# Episode: 307 Step: 42
# Episode: 308 Step: 54
# Episode: 309 Step: 113
# Episode: 310 Step: 32
# Episode: 311 Step: 75
# Loss : 326.627
# Episode: 312 Step: 30
# Episode: 313 Step: 12
# Episode: 314 Step: 10
# Episode: 315 Step: 38
# Episode: 316 Step: 31
# Episode: 317 Step: 60
# Episode: 318 Step: 9
# Episode: 319 Step: 28
# Episode: 320 Step: 30
# Episode: 321 Step: 27
# Loss : 29.0898
# Episode: 322 Step: 28
# Episode: 323 Step: 47
# Episode: 324 Step: 34
# Episode: 325 Step: 62
# Episode: 326 Step: 49
# Episode: 327 Step: 40
# Episode: 328 Step: 48
# Episode: 329 Step: 57
# Episode: 330 Step: 23
# Episode: 331 Step: 43
# Loss : 484.162
# Episode: 332 Step: 15
# Episode: 333 Step: 35
# Episode: 334 Step: 9
# Episode: 335 Step: 38
# Episode: 336 Step: 9
# Episode: 337 Step: 28
# Episode: 338 Step: 11
# Episode: 339 Step: 35
# Episode: 340 Step: 12
# Episode: 341 Step: 8
# Loss : 229.407
# Episode: 342 Step: 9
# Episode: 343 Step: 9
# Episode: 344 Step: 11
# Episode: 345 Step: 9
# Episode: 346 Step: 8
# Episode: 347 Step: 10
# Episode: 348 Step: 8
# Episode: 349 Step: 8
# Episode: 350 Step: 9
# Episode: 351 Step: 10
# Loss : 106.589
# Episode: 352 Step: 32
# Episode: 353 Step: 28
# Episode: 354 Step: 40
# Episode: 355 Step: 34
# Episode: 356 Step: 35
# Episode: 357 Step: 34
# Episode: 358 Step: 26
# Episode: 359 Step: 32
# Episode: 360 Step: 35
# Episode: 361 Step: 40
# Loss : 24.2657
# Episode: 362 Step: 47
# Episode: 363 Step: 58
# Episode: 364 Step: 51
# Episode: 365 Step: 59
# Episode: 366 Step: 61
# Episode: 367 Step: 78
# Episode: 368 Step: 49
# Episode: 369 Step: 31
# Episode: 370 Step: 34
# Episode: 371 Step: 32
# Loss : 20.1734
# Episode: 372 Step: 33
# Episode: 373 Step: 42
# Episode: 374 Step: 52
# Episode: 375 Step: 19
# Episode: 376 Step: 36
# Episode: 377 Step: 84
# Episode: 378 Step: 50
# Episode: 379 Step: 21
# Episode: 380 Step: 36
# Episode: 381 Step: 79
# Loss : 20961.1
# Episode: 382 Step: 31
# Episode: 383 Step: 75
# Episode: 384 Step: 49
# Episode: 385 Step: 62
# Episode: 386 Step: 67
# Episode: 387 Step: 40
# Episode: 388 Step: 27
# Episode: 389 Step: 27
# Episode: 390 Step: 46
# Episode: 391 Step: 41
# Loss : 113.829
# Episode: 392 Step: 21
# Episode: 393 Step: 11
# Episode: 394 Step: 10
# Episode: 395 Step: 8
# Episode: 396 Step: 30
# Episode: 397 Step: 30
# Episode: 398 Step: 9
# Episode: 399 Step: 9
# Episode: 400 Step: 25
# Episode: 401 Step: 46
# Loss : 31.9231
# Episode: 402 Step: 47
# Episode: 403 Step: 14
# Episode: 404 Step: 33
# Episode: 405 Step: 8
# Episode: 406 Step: 11
# Episode: 407 Step: 20
# Episode: 408 Step: 14
# Episode: 409 Step: 23
# Episode: 410 Step: 50
# Episode: 411 Step: 23
# Loss : 118.534
# Episode: 412 Step: 15
# Episode: 413 Step: 22
# Episode: 414 Step: 21
# Episode: 415 Step: 18
# Episode: 416 Step: 13
# Episode: 417 Step: 29
# Episode: 418 Step: 21
# Episode: 419 Step: 15
# Episode: 420 Step: 14
# Episode: 421 Step: 24
# Loss : 9917.44
# Episode: 422 Step: 60
# Episode: 423 Step: 18
# Episode: 424 Step: 12
# Episode: 425 Step: 19
# Episode: 426 Step: 12
# Episode: 427 Step: 10
# Episode: 428 Step: 11
# Episode: 429 Step: 13
# Episode: 430 Step: 10
# Episode: 431 Step: 12
# Loss : 75.434
# Episode: 432 Step: 10
# Episode: 433 Step: 10
# Episode: 434 Step: 9
# Episode: 435 Step: 8
# Episode: 436 Step: 9
# Episode: 437 Step: 10
# Episode: 438 Step: 10
# Episode: 439 Step: 10
# Episode: 440 Step: 9
# Episode: 441 Step: 9
# Loss : 17.9427
# Episode: 442 Step: 31
# Episode: 443 Step: 48
# Episode: 444 Step: 68
# Episode: 445 Step: 24
# Episode: 446 Step: 41
# Episode: 447 Step: 34
# Episode: 448 Step: 27
# Episode: 449 Step: 31
# Episode: 450 Step: 17
# Episode: 451 Step: 47
# Loss : 208.681
# Episode: 452 Step: 10
# Episode: 453 Step: 10
# Episode: 454 Step: 10
# Episode: 455 Step: 9
# Episode: 456 Step: 9
# Episode: 457 Step: 10
# Episode: 458 Step: 9
# Episode: 459 Step: 10
# Episode: 460 Step: 8
# Episode: 461 Step: 9
# Loss : 114.018
# Episode: 462 Step: 41
# Episode: 463 Step: 36
# Episode: 464 Step: 28
# Episode: 465 Step: 26
# Episode: 466 Step: 24
# Episode: 467 Step: 24
# Episode: 468 Step: 61
# Episode: 469 Step: 35
# Episode: 470 Step: 72
# Episode: 471 Step: 34
# Loss : 10903.5
# Episode: 472 Step: 89
# Episode: 473 Step: 27
# Episode: 474 Step: 54
# Episode: 475 Step: 37
# Episode: 476 Step: 29
# Episode: 477 Step: 33
# Episode: 478 Step: 45
# Episode: 479 Step: 107
# Episode: 480 Step: 65
# Episode: 481 Step: 64
# Loss : 11050.7
# Episode: 482 Step: 9
# Episode: 483 Step: 9
# Episode: 484 Step: 8
# Episode: 485 Step: 8
# Episode: 486 Step: 11
# Episode: 487 Step: 10
# Episode: 488 Step: 8
# Episode: 489 Step: 8
# Episode: 490 Step: 10
# Episode: 491 Step: 10
# Loss : 55.4522
# Episode: 492 Step: 21
# Episode: 493 Step: 33
# Episode: 494 Step: 30
# Episode: 495 Step: 33
# Episode: 496 Step: 31
# Episode: 497 Step: 30
# Episode: 498 Step: 33
# Episode: 499 Step: 20
# Episode: 500 Step: 25
# Episode: 501 Step: 29
# Loss : 67.7299
# Episode: 502 Step: 35
# Episode: 503 Step: 157
# Episode: 504 Step: 32
# Episode: 505 Step: 43
# Episode: 506 Step: 37
# Episode: 507 Step: 40
# Episode: 508 Step: 29
# Episode: 509 Step: 29
# Episode: 510 Step: 30
# Episode: 511 Step: 34
# Loss : 12567.8
# Episode: 512 Step: 68
# Episode: 513 Step: 53
# Episode: 514 Step: 60
# Episode: 515 Step: 55
# Episode: 516 Step: 69
# Episode: 517 Step: 52
# Episode: 518 Step: 72
# Episode: 519 Step: 41
# Episode: 520 Step: 53
# Episode: 521 Step: 59
# Loss : 20067.4
# Episode: 522 Step: 9
# Episode: 523 Step: 9
# Episode: 524 Step: 12
# Episode: 525 Step: 10
# Episode: 526 Step: 9
# Episode: 527 Step: 10
# Episode: 528 Step: 9
# Episode: 529 Step: 9
# Episode: 530 Step: 9
# Episode: 531 Step: 9
# Loss : 109.0
# Episode: 532 Step: 10
# Episode: 533 Step: 10
# Episode: 534 Step: 9
# Episode: 535 Step: 9
# Episode: 536 Step: 10
# Episode: 537 Step: 11
# Episode: 538 Step: 9
# Episode: 539 Step: 10
# Episode: 540 Step: 10
# Episode: 541 Step: 9
# Loss : 55.3737
# Episode: 542 Step: 72
# Episode: 543 Step: 57
# Episode: 544 Step: 77
# Episode: 545 Step: 59
# Episode: 546 Step: 55
# Episode: 547 Step: 60
# Episode: 548 Step: 44
# Episode: 549 Step: 60
# Episode: 550 Step: 78
# Episode: 551 Step: 53
# Loss : 10210.0
# Episode: 552 Step: 39
# Episode: 553 Step: 26
# Episode: 554 Step: 32
# Episode: 555 Step: 32
# Episode: 556 Step: 37
# Episode: 557 Step: 41
# Episode: 558 Step: 55
# Episode: 559 Step: 25
# Episode: 560 Step: 23
# Episode: 561 Step: 40
# Loss : 81.5455
# Episode: 562 Step: 27
# Episode: 563 Step: 9
# Episode: 564 Step: 28
# Episode: 565 Step: 39
# Episode: 566 Step: 11
# Episode: 567 Step: 28
# Episode: 568 Step: 9
# Episode: 569 Step: 20
# Episode: 570 Step: 11
# Episode: 571 Step: 34
# Loss : 21.5858
# Episode: 572 Step: 30
# Episode: 573 Step: 32
# Episode: 574 Step: 53
# Episode: 575 Step: 47
# Episode: 576 Step: 37
# Episode: 577 Step: 23
# Episode: 578 Step: 26
# Episode: 579 Step: 54
# Episode: 580 Step: 15
# Episode: 581 Step: 26
# Loss : 42.094
# Episode: 582 Step: 16
# Episode: 583 Step: 15
# Episode: 584 Step: 22
# Episode: 585 Step: 15
# Episode: 586 Step: 17
# Episode: 587 Step: 22
# Episode: 588 Step: 23
# Episode: 589 Step: 20
# Episode: 590 Step: 14
# Episode: 591 Step: 15
# Loss : 148.625
# Episode: 592 Step: 24
# Episode: 593 Step: 18
# Episode: 594 Step: 10
# Episode: 595 Step: 12
# Episode: 596 Step: 17
# Episode: 597 Step: 13
# Episode: 598 Step: 15
# Episode: 599 Step: 15
# Episode: 600 Step: 12
# Episode: 601 Step: 13
# Loss : 161.92
# Episode: 602 Step: 64
# Episode: 603 Step: 31
# Episode: 604 Step: 29
# Episode: 605 Step: 46
# Episode: 606 Step: 44
# Episode: 607 Step: 28
# Episode: 608 Step: 21
# Episode: 609 Step: 34
# Episode: 610 Step: 30
# Episode: 611 Step: 20
# Loss : 20707.2
# Episode: 612 Step: 19
# Episode: 613 Step: 15
# Episode: 614 Step: 22
# Episode: 615 Step: 33
# Episode: 616 Step: 20
# Episode: 617 Step: 34
# Episode: 618 Step: 28
# Episode: 619 Step: 21
# Episode: 620 Step: 27
# Episode: 621 Step: 15
# Loss : 11461.6
# Episode: 622 Step: 23
# Episode: 623 Step: 33
# Episode: 624 Step: 23
# Episode: 625 Step: 36
# Episode: 626 Step: 24
# Episode: 627 Step: 25
# Episode: 628 Step: 40
# Episode: 629 Step: 43
# Episode: 630 Step: 31
# Episode: 631 Step: 32
# Loss : 196.882
# Episode: 632 Step: 15
# Episode: 633 Step: 18
# Episode: 634 Step: 17
# Episode: 635 Step: 12
# Episode: 636 Step: 19
# Episode: 637 Step: 17
# Episode: 638 Step: 16
# Episode: 639 Step: 22
# Episode: 640 Step: 15
# Episode: 641 Step: 17
# Loss : 12425.7
# Episode: 642 Step: 22
# Episode: 643 Step: 16
# Episode: 644 Step: 21
# Episode: 645 Step: 20
# Episode: 646 Step: 17
# Episode: 647 Step: 19
# Episode: 648 Step: 21
# Episode: 649 Step: 17
# Episode: 650 Step: 33
# Episode: 651 Step: 14
# Loss : 205.461
# Episode: 652 Step: 36
# Episode: 653 Step: 17
# Episode: 654 Step: 17
# Episode: 655 Step: 17
# Episode: 656 Step: 40
# Episode: 657 Step: 18
# Episode: 658 Step: 18
# Episode: 659 Step: 14
# Episode: 660 Step: 34
# Episode: 661 Step: 14
# Loss : 101.223
# Episode: 662 Step: 44
# Episode: 663 Step: 38
# Episode: 664 Step: 50
# Episode: 665 Step: 24
# Episode: 666 Step: 27
# Episode: 667 Step: 52
# Episode: 668 Step: 41
# Episode: 669 Step: 24
# Episode: 670 Step: 29
# Episode: 671 Step: 28
# Loss : 33456.0
# Episode: 672 Step: 10
# Episode: 673 Step: 9
# Episode: 674 Step: 9
# Episode: 675 Step: 9
# Episode: 676 Step: 8
# Episode: 677 Step: 9
# Episode: 678 Step: 9
# Episode: 679 Step: 10
# Episode: 680 Step: 9
# Episode: 681 Step: 10
# Loss : 232.745
# Episode: 682 Step: 33
# Episode: 683 Step: 48
# Episode: 684 Step: 65
# Episode: 685 Step: 50
# Episode: 686 Step: 33
# Episode: 687 Step: 124
# Episode: 688 Step: 46
# Episode: 689 Step: 43
# Episode: 690 Step: 87
# Episode: 691 Step: 61
# Loss : 33.6267
# Episode: 692 Step: 61
# Episode: 693 Step: 57
# Episode: 694 Step: 62
# Episode: 695 Step: 50
# Episode: 696 Step: 44
# Episode: 697 Step: 65
# Episode: 698 Step: 34
# Episode: 699 Step: 48
# Episode: 700 Step: 44
# Episode: 701 Step: 30
# Loss : 9798.96
# Episode: 702 Step: 28
# Episode: 703 Step: 21
# Episode: 704 Step: 22
# Episode: 705 Step: 36
# Episode: 706 Step: 30
# Episode: 707 Step: 37
# Episode: 708 Step: 35
# Episode: 709 Step: 16
# Episode: 710 Step: 42
# Episode: 711 Step: 28
# Loss : 22.693
# Episode: 712 Step: 100
# Episode: 713 Step: 25
# Episode: 714 Step: 53
# Episode: 715 Step: 49
# Episode: 716 Step: 35
# Episode: 717 Step: 60
# Episode: 718 Step: 24
# Episode: 719 Step: 38
# Episode: 720 Step: 29
# Episode: 721 Step: 73
# Loss : 113.269
# Episode: 722 Step: 110
# Episode: 723 Step: 102
# Episode: 724 Step: 106
# Episode: 725 Step: 99
# Episode: 726 Step: 91
# Episode: 727 Step: 97
# Episode: 728 Step: 81
# Episode: 729 Step: 109
# Episode: 730 Step: 105
# Episode: 731 Step: 144
# Loss : 12215.2
# Episode: 732 Step: 143
# Episode: 733 Step: 127
# Episode: 734 Step: 60
# Episode: 735 Step: 132
# Episode: 736 Step: 67
# Episode: 737 Step: 70
# Episode: 738 Step: 68
# Episode: 739 Step: 79
# Episode: 740 Step: 83
# Episode: 741 Step: 90
# Loss : 17841.5
# Episode: 742 Step: 54
# Episode: 743 Step: 36
# Episode: 744 Step: 69
# Episode: 745 Step: 42
# Episode: 746 Step: 62
# Episode: 747 Step: 70
# Episode: 748 Step: 41
# Episode: 749 Step: 44
# Episode: 750 Step: 59
# Episode: 751 Step: 36
# Loss : 108.467
# Episode: 752 Step: 9
# Episode: 753 Step: 10
# Episode: 754 Step: 9
# Episode: 755 Step: 9
# Episode: 756 Step: 8
# Episode: 757 Step: 9
# Episode: 758 Step: 9
# Episode: 759 Step: 8
# Episode: 760 Step: 10
# Episode: 761 Step: 10
# Loss : 38.1287
# Episode: 762 Step: 37
# Episode: 763 Step: 21
# Episode: 764 Step: 25
# Episode: 765 Step: 19
# Episode: 766 Step: 31
# Episode: 767 Step: 34
# Episode: 768 Step: 22
# Episode: 769 Step: 26
# Episode: 770 Step: 39
# Episode: 771 Step: 27
# Loss : 21.8902
# Episode: 772 Step: 81
# Episode: 773 Step: 37
# Episode: 774 Step: 55
# Episode: 775 Step: 48
# Episode: 776 Step: 33
# Episode: 777 Step: 56
# Episode: 778 Step: 42
# Episode: 779 Step: 38
# Episode: 780 Step: 40
# Episode: 781 Step: 119
# Loss : 203.95
# Episode: 782 Step: 56
# Episode: 783 Step: 94
# Episode: 784 Step: 80
# Episode: 785 Step: 72
# Episode: 786 Step: 60
# Episode: 787 Step: 168
# Episode: 788 Step: 54
# Episode: 789 Step: 82
# Episode: 790 Step: 73
# Episode: 791 Step: 66
