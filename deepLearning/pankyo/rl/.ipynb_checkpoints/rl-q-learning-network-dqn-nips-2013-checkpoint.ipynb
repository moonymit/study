# %%
import numpy as np
import tensorflow as tf
import random

class DQN:
    def __init__(self, session, input_size, output_size, name="main"):
        
        self.session = session
        self.input_size = input_size
        self.output_size = output_size
        self.net_name = name
        
        self.build_network()

    
    # h_size: hidden size, l_rate: learning rate
    def build_network(self, h_size = 10, l_rate = 1e-1):
        with tf.variable_scope(self.net_name):
            self._X=tf.placeholder(dtype=tf.float32, shape=[None, self.input_size])

            # First layer of weights
            W1 = tf.get_variable('W1', shape=[self.input_size, h_size], 
                                 initializer=tf.contrib.layers.xavier_initializer())
            layer1 = tf.nn.tanh(tf.matmul(self._X, W1))

            # Second layer of weights
            W2 = tf.get_variable('W2', shape=[h_size, self.output_size], 
                                 initializer=tf.contrib.layers.xavier_initializer())

            # Q prediction
            self._Qpred = tf.matmul(layer1, W2)
        
        # We need to define the parts of the network needed for learning a polilcy
        self._Y = tf.placeholder(dtype=tf.float32, shape=[None, self.output_size])
        
        # Loss function
        self._loss = tf.reduce_sum(tf.square(self._Y - self._Qpred))
        
        # Learning
        self._train = tf.train.AdamOptimizer(learning_rate=l_rate).minimize(self._loss)
    

    def predict(self, state):
        s_t = np.reshape(state, [1,self.input_size])
        return self.session.run(self._Qpred, feed_dict={self._X: s_t})

    
    def update(self, x_stack, y_stack):
        return self.session.run([self._loss, self._train], feed_dict={self._X: x_stack, self._Y: y_stack})

# %%
from collections import deque
import gym
from gym.envs.registration import register

env = gym.make('CartPole-v0')
env._max_episode_steps = 10004

input_size = env.observation_space.shape[0]
output_size = env.action_space.n

dis = 0.9
REPLAY_MEMORY = 50000

def simple_replay_train(DQN, train_batch):
    x_stack = np.empty(0).reshape(0, DQN.input_size)
    y_stack = np.empty(0).reshape(0, DQN.output_size)
    
    # Get stored information from the buffer
    for state, action, reward, next_state, done in train_batch:
        Q = DQN.predict(state)
        
        # terminal?
        if done:
            Q[0, action] = reward
        else:
            # Obtain the Q' values by feeding the new state through our network
            Q[0, action] = reward + dis * np.max(DQN.predict(next_state))
            
        y_stack = np.vstack([y_stack, Q])
        x_stack = np.vstack([x_stack, state])
    
    # Train our network using target and predicted Q values on each episode
    return DQN.update(x_stack, y_stack)


def bot_play(mainDQN):
    # See our trained network in action
    s = env.reset()
    reward_sum = 0
    while True:
        env.render()
        a = np.argmax(mainDQN.predict(s))
        s, reward, done, _ = env.step(a)
        reward_sum += reward
        if done:
            print("Total score: {}".format(reward_sum))
            break
            

def main():
    max_episodes = 5000
    
    # store the previus observations in replay memory
    replay_buffer = deque()
    
    with tf.Session() as sess:
        mainDQN = DQN(sess, input_size, output_size)
        tf.global_variables_initializer().run()
        
        for episode in range(max_episodes):
            e = 1. / ((episode / 10) + 1)
            done = False
            step_count = 0
            
            state = env.reset()
            
            while not done:
                if np.random.rand(1) < e:
                    action = env.action_space.sample()
                else:
                    #choose an action by greedily from the Q-network
                    action = np.argmax(mainDQN.predict(state))
                    
                # Get new state and reward from environment
                next_state, reward, done, _ = env.step(action)
                if done: # Penalty
                    reward = -100
                    
                # Save the experience to our buffer
                replay_buffer.append((state, action, reward, next_state, done))
                
                if len(replay_buffer) > REPLAY_MEMORY:
                    replay_buffer.popleft()
                    
                state = next_state
                step_count += 1
                if step_count > 10000: # Enough
                    break
                    
            print("Episode: {} Step: {}".format(episode, step_count))
            if step_count > 10000:
                pass
                break
            
            if episode % 10 == 1: # train every 10 episodes
                # Get a random batch of experiences.
                for _ in range(50):
                    #Minibatch works better
                    minibatch = random.sample(replay_buffer, 10)
                    loss, _ = simple_replay_train(mainDQN, minibatch)
                print("Loss :", loss)
            
        bot_play(mainDQN)
# Out:
# [2017-08-04 05:33:24,163] Making new env: CartPole-v0

# %%
if __name__ == "__main__":
    main()
# Out:
# Episode: 0 Step: 13
# Episode: 1 Step: 12
# Loss : 8137.51
# Episode: 2 Step: 18
# Episode: 3 Step: 17
# Episode: 4 Step: 12
# Episode: 5 Step: 22
# Episode: 6 Step: 13
# Episode: 7 Step: 9
# Episode: 8 Step: 11
# Episode: 9 Step: 12
# Episode: 10 Step: 9
# Episode: 11 Step: 15
# Loss : 54.2469
# Episode: 12 Step: 10
# Episode: 13 Step: 9
# Episode: 14 Step: 11
# Episode: 15 Step: 12
# Episode: 16 Step: 9
# Episode: 17 Step: 13
# Episode: 18 Step: 10
# Episode: 19 Step: 8
# Episode: 20 Step: 17
# Episode: 21 Step: 9
# Loss : 9782.82
# Episode: 22 Step: 16
# Episode: 23 Step: 18
# Episode: 24 Step: 14
# Episode: 25 Step: 20
# Episode: 26 Step: 18
# Episode: 27 Step: 21
# Episode: 28 Step: 17
# Episode: 29 Step: 18
# Episode: 30 Step: 14
# Episode: 31 Step: 18
# Loss : 9719.95
# Episode: 32 Step: 26
# Episode: 33 Step: 38
# Episode: 34 Step: 24
# Episode: 35 Step: 24
# Episode: 36 Step: 53
# Episode: 37 Step: 28
# Episode: 38 Step: 26
# Episode: 39 Step: 21
# Episode: 40 Step: 21
# Episode: 41 Step: 30
# Loss : 132.385
# Episode: 42 Step: 11
# Episode: 43 Step: 9
# Episode: 44 Step: 9
# Episode: 45 Step: 11
# Episode: 46 Step: 9
# Episode: 47 Step: 10
# Episode: 48 Step: 10
# Episode: 49 Step: 9
# Episode: 50 Step: 11
# Episode: 51 Step: 8
# Loss : 21726.0
# Episode: 52 Step: 9
# Episode: 53 Step: 9
# Episode: 54 Step: 10
# Episode: 55 Step: 10
# Episode: 56 Step: 10
# Episode: 57 Step: 10
# Episode: 58 Step: 10
# Episode: 59 Step: 9
# Episode: 60 Step: 11
# Episode: 61 Step: 9
# Loss : 284.54
# Episode: 62 Step: 70
# Episode: 63 Step: 74
# Episode: 64 Step: 89
# Episode: 65 Step: 57
# Episode: 66 Step: 74
# Episode: 67 Step: 59
# Episode: 68 Step: 355
# Episode: 69 Step: 58
# Episode: 70 Step: 60
# Episode: 71 Step: 76
# Loss : 235.112
# Episode: 72 Step: 129
# Episode: 73 Step: 134
# Episode: 74 Step: 133
# Episode: 75 Step: 149
# Episode: 76 Step: 131
# Episode: 77 Step: 216
# Episode: 78 Step: 122
# Episode: 79 Step: 104
# Episode: 80 Step: 86
# Episode: 81 Step: 58
# Loss : 167.649
# Episode: 82 Step: 55
# Episode: 83 Step: 57
# Episode: 84 Step: 55
# Episode: 85 Step: 53
# Episode: 86 Step: 68
# Episode: 87 Step: 50
# Episode: 88 Step: 56
# Episode: 89 Step: 43
# Episode: 90 Step: 57
# Episode: 91 Step: 149
# Loss : 100.467
# Episode: 92 Step: 25
# Episode: 93 Step: 26
# Episode: 94 Step: 48
# Episode: 95 Step: 34
# Episode: 96 Step: 23
# Episode: 97 Step: 45
# Episode: 98 Step: 28
# Episode: 99 Step: 24
# Episode: 100 Step: 41
# Episode: 101 Step: 25
# Loss : 60.0646
# Episode: 102 Step: 10
# Episode: 103 Step: 10
# Episode: 104 Step: 9
# Episode: 105 Step: 9
# Episode: 106 Step: 8
# Episode: 107 Step: 8
# Episode: 108 Step: 10
# Episode: 109 Step: 23
# Episode: 110 Step: 10
# Episode: 111 Step: 10
# Loss : 9471.84
# Episode: 112 Step: 123
# Episode: 113 Step: 141
# Episode: 114 Step: 138
# Episode: 115 Step: 132
# Episode: 116 Step: 197
# Episode: 117 Step: 171
# Episode: 118 Step: 131
# Episode: 119 Step: 187
# Episode: 120 Step: 180
# Episode: 121 Step: 81
# Loss : 96.7925
# Episode: 122 Step: 23
# Episode: 123 Step: 28
# Episode: 124 Step: 30
# Episode: 125 Step: 32
# Episode: 126 Step: 27
# Episode: 127 Step: 26
# Episode: 128 Step: 23
# Episode: 129 Step: 27
# Episode: 130 Step: 25
# Episode: 131 Step: 29
# Loss : 51.1477
# Episode: 132 Step: 53
# Episode: 133 Step: 114
# Episode: 134 Step: 166
# Episode: 135 Step: 86
# Episode: 136 Step: 187
# Episode: 137 Step: 250
# Episode: 138 Step: 136
# Episode: 139 Step: 88
# Episode: 140 Step: 138
# Episode: 141 Step: 99
# Loss : 73.4127
# Episode: 142 Step: 126
# Episode: 143 Step: 233
# Episode: 144 Step: 161
# Episode: 145 Step: 153
# Episode: 146 Step: 176
# Episode: 147 Step: 147
# Episode: 148 Step: 147
# Episode: 149 Step: 181
# Episode: 150 Step: 169
# Episode: 151 Step: 130
# Loss : 33.5491
# Episode: 152 Step: 25
# Episode: 153 Step: 34
# Episode: 154 Step: 22
# Episode: 155 Step: 28
# Episode: 156 Step: 25
# Episode: 157 Step: 28
# Episode: 158 Step: 28
# Episode: 159 Step: 32
# Episode: 160 Step: 28
# Episode: 161 Step: 39
# Loss : 9693.65
# Episode: 162 Step: 77
# Episode: 163 Step: 60
# Episode: 164 Step: 172
# Episode: 165 Step: 60
# Episode: 166 Step: 61
# Episode: 167 Step: 68
# Episode: 168 Step: 107
# Episode: 169 Step: 61
# Episode: 170 Step: 71
# Episode: 171 Step: 58
# Loss : 123.658
# Episode: 172 Step: 138
# Episode: 173 Step: 135
# Episode: 174 Step: 55
# Episode: 175 Step: 51
# Episode: 176 Step: 59
# Episode: 177 Step: 71
# Episode: 178 Step: 130
# Episode: 179 Step: 70
# Episode: 180 Step: 46
# Episode: 181 Step: 55
# Loss : 103.974
# Episode: 182 Step: 73
# Episode: 183 Step: 93
# Episode: 184 Step: 121
# Episode: 185 Step: 153
# Episode: 186 Step: 119
# Episode: 187 Step: 113
# Episode: 188 Step: 112
# Episode: 189 Step: 86
# Episode: 190 Step: 89
# Episode: 191 Step: 120
# Loss : 144.736
# Episode: 192 Step: 31
# Episode: 193 Step: 33
# Episode: 194 Step: 67
# Episode: 195 Step: 32
# Episode: 196 Step: 40
# Episode: 197 Step: 25
# Episode: 198 Step: 49
# Episode: 199 Step: 20
# Episode: 200 Step: 28
# Episode: 201 Step: 26
# Loss : 9985.27
# Episode: 202 Step: 13
# Episode: 203 Step: 20
# Episode: 204 Step: 22
# Episode: 205 Step: 15
# Episode: 206 Step: 19
# Episode: 207 Step: 16
# Episode: 208 Step: 20
# Episode: 209 Step: 18
# Episode: 210 Step: 17
# Episode: 211 Step: 18
# Loss : 43.0756
# Episode: 212 Step: 9
# Episode: 213 Step: 12
# Episode: 214 Step: 9
# Episode: 215 Step: 23
# Episode: 216 Step: 14
# Episode: 217 Step: 14
# Episode: 218 Step: 10
# Episode: 219 Step: 10
# Episode: 220 Step: 21
# Episode: 221 Step: 26
# Loss : 15.4189
# Episode: 222 Step: 31
# Episode: 223 Step: 34
# Episode: 224 Step: 23
# Episode: 225 Step: 27
# Episode: 226 Step: 30
# Episode: 227 Step: 55
# Episode: 228 Step: 24
# Episode: 229 Step: 22
# Episode: 230 Step: 26
# Episode: 231 Step: 30
# Loss : 38.9962
# Episode: 232 Step: 14
# Episode: 233 Step: 25
# Episode: 234 Step: 12
# Episode: 235 Step: 13
# Episode: 236 Step: 16
# Episode: 237 Step: 12
# Episode: 238 Step: 13
# Episode: 239 Step: 18
# Episode: 240 Step: 11
# Episode: 241 Step: 17
# Loss : 9943.3
# Episode: 242 Step: 30
# Episode: 243 Step: 56
# Episode: 244 Step: 28
# Episode: 245 Step: 24
# Episode: 246 Step: 32
# Episode: 247 Step: 40
# Episode: 248 Step: 34
# Episode: 249 Step: 49
# Episode: 250 Step: 27
# Episode: 251 Step: 24
# Loss : 7.03948
# Episode: 252 Step: 33
# Episode: 253 Step: 38
# Episode: 254 Step: 23
# Episode: 255 Step: 31
# Episode: 256 Step: 42
# Episode: 257 Step: 34
# Episode: 258 Step: 44
# Episode: 259 Step: 39
# Episode: 260 Step: 35
# Episode: 261 Step: 76
# Loss : 57.9271
# Episode: 262 Step: 22
# Episode: 263 Step: 23
# Episode: 264 Step: 21
# Episode: 265 Step: 23
# Episode: 266 Step: 49
# Episode: 267 Step: 26
# Episode: 268 Step: 25
# Episode: 269 Step: 20
# Episode: 270 Step: 25
# Episode: 271 Step: 22
# Loss : 24.4108
# Episode: 272 Step: 10
# Episode: 273 Step: 9
# Episode: 274 Step: 9
# Episode: 275 Step: 10
# Episode: 276 Step: 9
# Episode: 277 Step: 9
# Episode: 278 Step: 9
# Episode: 279 Step: 9
# Episode: 280 Step: 11
# Episode: 281 Step: 8
# Loss : 9261.16
# Episode: 282 Step: 44
# Episode: 283 Step: 75
# Episode: 284 Step: 41
# Episode: 285 Step: 76
# Episode: 286 Step: 42
# Episode: 287 Step: 39
# Episode: 288 Step: 70
# Episode: 289 Step: 179
# Episode: 290 Step: 94
# Episode: 291 Step: 48
# Loss : 356.616
# Episode: 292 Step: 51
# Episode: 293 Step: 29
# Episode: 294 Step: 44
# Episode: 295 Step: 47
# Episode: 296 Step: 34
# Episode: 297 Step: 49
# Episode: 298 Step: 28
# Episode: 299 Step: 75
# Episode: 300 Step: 40
# Episode: 301 Step: 49
# Loss : 11055.4
# Episode: 302 Step: 56
# Episode: 303 Step: 55
# Episode: 304 Step: 37
# Episode: 305 Step: 56
# Episode: 306 Step: 44
# Episode: 307 Step: 29
# Episode: 308 Step: 40
# Episode: 309 Step: 45
# Episode: 310 Step: 35
# Episode: 311 Step: 46
# Loss : 65.498
# Episode: 312 Step: 107
# Episode: 313 Step: 97
# Episode: 314 Step: 87
# Episode: 315 Step: 66
# Episode: 316 Step: 56
# Episode: 317 Step: 105
# Episode: 318 Step: 54
# Episode: 319 Step: 105
# Episode: 320 Step: 85
# Episode: 321 Step: 73
# Loss : 10169.9
# Episode: 322 Step: 24
# Episode: 323 Step: 26
# Episode: 324 Step: 11
# Episode: 325 Step: 21
# Episode: 326 Step: 13
# Episode: 327 Step: 15
# Episode: 328 Step: 13
# Episode: 329 Step: 24
# Episode: 330 Step: 24
# Episode: 331 Step: 22
# Loss : 19.6222
# Episode: 332 Step: 10
# Episode: 333 Step: 10
# Episode: 334 Step: 10
# Episode: 335 Step: 10
# Episode: 336 Step: 9
# Episode: 337 Step: 8
# Episode: 338 Step: 10
# Episode: 339 Step: 10
# Episode: 340 Step: 10
# Episode: 341 Step: 10
# Loss : 81.2203
# Episode: 342 Step: 34
# Episode: 343 Step: 136
# Episode: 344 Step: 145
# Episode: 345 Step: 43
# Episode: 346 Step: 80
# Episode: 347 Step: 52
# Episode: 348 Step: 36
# Episode: 349 Step: 48
# Episode: 350 Step: 138
# Episode: 351 Step: 61
# Loss : 46.9696
# Episode: 352 Step: 270
# Episode: 353 Step: 80
# Episode: 354 Step: 340
# Episode: 355 Step: 625
# Episode: 356 Step: 92
# Episode: 357 Step: 301
# Episode: 358 Step: 83
# Episode: 359 Step: 112
# Episode: 360 Step: 364
# Episode: 361 Step: 400
# Loss : 10407.9
# Episode: 362 Step: 23
# Episode: 363 Step: 25
# Episode: 364 Step: 31
# Episode: 365 Step: 31
# Episode: 366 Step: 29
# Episode: 367 Step: 24
# Episode: 368 Step: 32
# Episode: 369 Step: 26
# Episode: 370 Step: 28
# Episode: 371 Step: 26
# Loss : 42.5277
# Episode: 372 Step: 67
# Episode: 373 Step: 29
# Episode: 374 Step: 30
# Episode: 375 Step: 64
# Episode: 376 Step: 77
# Episode: 377 Step: 51
# Episode: 378 Step: 27
# Episode: 379 Step: 67
# Episode: 380 Step: 31
# Episode: 381 Step: 51
# Loss : 59.7907
# Episode: 382 Step: 50
# Episode: 383 Step: 28
# Episode: 384 Step: 31
# Episode: 385 Step: 32
# Episode: 386 Step: 51
# Episode: 387 Step: 44
# Episode: 388 Step: 38
# Episode: 389 Step: 34
# Episode: 390 Step: 35
# Episode: 391 Step: 34
# Loss : 42.3401
# Episode: 392 Step: 26
# Episode: 393 Step: 19
# Episode: 394 Step: 28
# Episode: 395 Step: 21
# Episode: 396 Step: 21
# Episode: 397 Step: 21
# Episode: 398 Step: 21
# Episode: 399 Step: 27
# Episode: 400 Step: 43
# Episode: 401 Step: 21
# Loss : 28.82
# Episode: 402 Step: 26
# Episode: 403 Step: 27
# Episode: 404 Step: 26
# Episode: 405 Step: 21
# Episode: 406 Step: 28
# Episode: 407 Step: 21
# Episode: 408 Step: 21
# Episode: 409 Step: 29
# Episode: 410 Step: 27
# Episode: 411 Step: 22
# Loss : 61.8965
# Episode: 412 Step: 191
# Episode: 413 Step: 246
# Episode: 414 Step: 93
# Episode: 415 Step: 176
# Episode: 416 Step: 219
# Episode: 417 Step: 280
# Episode: 418 Step: 110
# Episode: 419 Step: 195
# Episode: 420 Step: 211
# Episode: 421 Step: 88
# Loss : 50.6156
# Episode: 422 Step: 16
# Episode: 423 Step: 12
# Episode: 424 Step: 15
# Episode: 425 Step: 12
# Episode: 426 Step: 16
# Episode: 427 Step: 14
# Episode: 428 Step: 17
# Episode: 429 Step: 13
# Episode: 430 Step: 15
# Episode: 431 Step: 16
# Loss : 95.7703
# Episode: 432 Step: 10001
